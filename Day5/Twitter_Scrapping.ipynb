# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob

# %%
#Corona Virus
class TwitterClient(object): 
    def __init__(self): 
        consumer_key = 'UP58QSui5J78pjsTK6giWNvCZ'
        consumer_secret = 'tIKjFuqmfNwgczHn5Zp4ZEYb20H1mZEn8ta9SgQZjYbevoZ75N'
        access_token = '854948293868011520-Q0fXtOqa6cVeJQX5LrKiH6NaHV5KvAK'
        access_token_secret = '4zLBMAPlqWiF0EQwbZsMeWzX4778CwCjBf4ABd2P5N2Gd'

        try: 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            self.auth.set_access_token(access_token, access_token_secret) 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        tweets = [] 
  
        try: 
            fetched_tweets = self.api.search(q = query, count = count) 
            for tweet in fetched_tweets: 
                parsed_tweet = {} 
                parsed_tweet['text'] = tweet.text 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                if tweet.retweet_count > 0:  
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
            return tweets 
  
        except tweepy.TweepError as e: 
            print("Error : " + str(e)) 
def main(): 
    api = TwitterClient() 
    tweets = api.get_tweets(query = 'Corona Virus', count = 200) 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text'])  
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
if __name__ == "__main__":  
    main()
# Out:
# Positive tweets percentage: 32.95454545454545 %
# Negative tweets percentage: 67.04545454545455 %
#
#
# Positive tweets:
# RT @SaithAbdullah99: My younger brother and my father also tested positive for corona virus, me and my sisters will give our samples now, p…
# @Zulu_008 My best friend had his birthday cucked by the Corona virus and he was born in april. Could believe it tbh
# RT @AshworthJackson: They’re getting really defensive about the whole 5G corona virus thing. Really makes you wonder if there’s something t…
# RT @D_Gitonyi: #UhuruDONTOpen
# The cities and countries where Corona virus has raged out of control have suffered near economic collapse due…
# RT @JoshOG: Corona Virus Easter Egg in COD Modern Warfare https://t.co/4dEgDty0y0
# RT @tom71266902: Really trying to get my head round this #corona virus in Scotland , the question I’m really struggling with is - What was…
# ...

# %%
#Narendra Modi
class TwitterClient(object): 
    def __init__(self): 
        consumer_key = 'UP58QSui5J78pjsTK6giWNvCZ'
        consumer_secret = 'tIKjFuqmfNwgczHn5Zp4ZEYb20H1mZEn8ta9SgQZjYbevoZ75N'
        access_token = '854948293868011520-Q0fXtOqa6cVeJQX5LrKiH6NaHV5KvAK'
        access_token_secret = '4zLBMAPlqWiF0EQwbZsMeWzX4778CwCjBf4ABd2P5N2Gd'

        try: 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            self.auth.set_access_token(access_token, access_token_secret) 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        tweets = [] 
  
        try: 
            fetched_tweets = self.api.search(q = query, count = count) 
            for tweet in fetched_tweets: 
                parsed_tweet = {} 
                parsed_tweet['text'] = tweet.text 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                if tweet.retweet_count > 0:  
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
            return tweets 
  
        except tweepy.TweepError as e: 
            print("Error : " + str(e)) 
def main(): 
    api = TwitterClient() 
    tweets = api.get_tweets(query = 'Narendra Modi', count = 200) 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text'])  
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
if __name__ == "__main__":  
    main()
# Out:
# Positive tweets percentage: 31.147540983606557 %
# Negative tweets percentage: 68.85245901639344 %
#
#
# Positive tweets:
# RT @sanjeevsanyal: "What is Atmanirbhar Bharat?"
# My column in today's Indian Express on the intellectual roots of the term, its economic im…
# RT @SidrahDP: @ranjona Everyone except Narendra Modi is responsible for Narendra Modi's actions.
# RT @MUKANGIRA1: Thank you very much HE Paul Kagame @PaulKagame Pres.of Rda and Rt Hon.Modi Narendra @narendramodi PM of India, for your tod…
# RT @Dharamp93654723: @cmohry @narendramodi @mlkhattar We're proud of our PM Shri Narendra Modi our real Hero but why the students of World…
# RT @Loquacious_Lion: @bsindia @ShekharGupta Didnt Modi G warned the Babus in November?
#
# You mean Babus dont care about the strongest most p…
# RT @NMAppVrtualMeet: ***Live***
#
# Join an exciting and interesting event '#BuildingSwasthBharat' organised by Narendra Modi App
#
# On 5th Jun,…
# ...

# %%
#Nisarga
class TwitterClient(object): 
    def __init__(self): 
        consumer_key = 'UP58QSui5J78pjsTK6giWNvCZ'
        consumer_secret = 'tIKjFuqmfNwgczHn5Zp4ZEYb20H1mZEn8ta9SgQZjYbevoZ75N'
        access_token = '854948293868011520-Q0fXtOqa6cVeJQX5LrKiH6NaHV5KvAK'
        access_token_secret = '4zLBMAPlqWiF0EQwbZsMeWzX4778CwCjBf4ABd2P5N2Gd'

        try: 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            self.auth.set_access_token(access_token, access_token_secret) 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        tweets = [] 
  
        try: 
            fetched_tweets = self.api.search(q = query, count = count) 
            for tweet in fetched_tweets: 
                parsed_tweet = {} 
                parsed_tweet['text'] = tweet.text 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
                if tweet.retweet_count > 0:  
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
            return tweets 
  
        except tweepy.TweepError as e: 
            print("Error : " + str(e)) 
def main(): 
    api = TwitterClient() 
    tweets = api.get_tweets(query = 'Nisarga', count = 200) 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text'])  
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
if __name__ == "__main__":  
    main()
# Out:
# Positive tweets percentage: 26.666666666666668 %
# Negative tweets percentage: 73.33333333333333 %
#
#
# Positive tweets:
# @sandeep49177950 Hi! Your Airtel network could be experiencing disruptions in certain flood affected areas due to C… https://t.co/lc8opcWdpH
# Situation at Velas, Ratnagiri, post Cyclone Nisarga
#
# The village which is famous for its Turtle Festival &amp; Turtle C… https://t.co/kxWBXk9Utk
# @romeopathic @mybmc @mybmcWardL Tree was fallen due to Cyclone Nisarga
# And @mybmcWardL quickly responded to spot a… https://t.co/JPP7AWM3Ex
# Salman khan’s farm house gets damaged due to Cyclone Nisarga: As all are well aware, the… https://t.co/Nj8uo0z8Ux
# RT @IndiaToday: #Mumbai escapes #CycloneNisarga's fury; India's #corona cases cross 2 lakh-mark; Watch this and more on #NewsToday with @sa…
# @IamOnir @mybmc Yesterday was #EnvironmentDay2020 Every leaders busy in posting pics with plants in their garden
# B… https://t.co/lEjf7U98wr
# ...
